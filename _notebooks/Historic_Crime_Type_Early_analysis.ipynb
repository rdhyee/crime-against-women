# %%
# %pylab --no-import-all inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import os
import pandas as pd
import codecs

from pandas import DataFrame, Series

# %%
FILES_DIR = os.path.join(os.pardir, "_data")
currentFile = codecs.open(os.path.join(FILES_DIR,'historicCrimeTypeYearly.csv'), encoding='iso-8859-1')

# Create the data frame
df = pd.read_csv(currentFile)

# %%
#Check rthat dataframe works
df
# Out:
#                                            CRIME HEAD    2001    2002    2003  \
# 0                                                Rape   16075   16373   15847
# 1           Kidnapping and Abduction of Women & Girls   14645   14506   13296
# 2                                        Dowry Deaths    6851    6822    6208
# 3   Assault on women with intent to outrage her mo...   34124   33943   32939
# 4                      Insult to the modesty of Women    9746   10155   12325
# 5                 Cruelty by Husband or his relatives   49170   49237   50703
# 6           Importation of Girls from Foreign Country     114      76      46
# 7                             Immoral Traffic (P) Act    8796    6598    5510
# 8                               Dowry Prohibition Act    3222    2816    2684
# 9            Indecent Representation of Women (P) Act    1052    2508    1043
# 10                         Commission of Sati (P) Act       0       0       0
# ...

# %%
# Next task find the most for each year, and which crime follows with that
# Apply matplotlib
import matplotlib.pyplot as plt

plt.figure()
df.plot()

# %%
new_df=df.transpose()
new_df
# Out:
#                0                                          1             2   \
# CRIME HEAD   Rape  Kidnapping and Abduction of Women & Girls  Dowry Deaths
# 2001        16075                                      14645          6851
# 2002        16373                                      14506          6822
# 2003        15847                                      13296          6208
# 2004        18233                                      15578          7026
# 2005        18359                                      15750          6787
# 2006        19348                                      17414          7618
# 2007        20737                                      20416          8093
# 2008        21467                                      22939          8172
# 2009        21397                                      25741          8383
# 2010        22172                                      29795          8391
# ...

# %%
# Index for the years, 
idx=new_df.index[1::]


new_df[10]
# Out:
# CRIME HEAD    Commission of Sati (P) Act
# 2001                                   0
# 2002                                   0
# 2003                                   0
# 2004                                   0
# 2005                                   1
# 2006                                   0
# 2007                                   0
# 2008                                   1
# 2009                                   0
# 2010                                   0
# 2011                                   1
# 2012                                   0
# Name: 10, dtype: object

# %%
i=0
plt.figure()
while i <11:
    plt.plot(idx, new_df[i][1::])
    i+=1
plt.show()
    #plt.legend(loc='best')

# %%
plt.show()

# %%
i=0    
for i in range (0,12):    
    b=plt.plot(idx, new_df[i][1::])
    i+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-266-38cffc60a8b2> in <module>()
#       1 i=0
#       2 for i in range (0,12):
# ----> 3     b=plt.plot(idx, new_df[i][1:11])
#       4     i+=1
#       5
#
# /Users/arezuaghaseyedjavadi/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /Users/arezuaghaseyedjavadi/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-262-e6d4cffce34b> in <module>()
# ----> 1 plt.b
#
# AttributeError: 'module' object has no attribute 'b'

# %%
# Most inefficient way, ever. 

rape_list=[]

for each in df[0]:
    rape_list.append(each)

rape_list=rape_list[1::]
print rape_list
    
year= ['2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012']

plt.plot(year, rape_list)
# Out:
# [16075, 16373, 15847, 18233, 18359, 19348, 20737, 21467, 21397, 22172, 24206, 24923]
